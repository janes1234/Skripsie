# %% [markdown]
# <h1>WWTW CNN — Data Exploration</h1>
#
# Quick sanity checks on the dataset before training: class balance, per-facility split distribution, and a preview of an augmented batch. Uses the shared config/data pipeline from `wwtw_utils.py`, so `COMPONENT` and image size here match what the training notebooks will use.

# %%
from wwtw_utils import *

# %% [markdown]
# <h1>Image Distribution</h1>

# %%
import re
import calendar
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from collections import defaultdict

# Setup paths based on your project structure
RAW_DATA_ROOT = Path("../wastewater")
IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".tif", ".tiff"}

# Grouping all sub-directories by their main facility
FACILITIES = {
    "Atlantis": [
        "Atlantis/Images"
    ],
    "CapeFlats": [
        "CapeFlats/Images/CF1", 
        "CapeFlats/Images/CF2", 
        "CapeFlats/Images/CF3", 
        "CapeFlats/Images/CF4"
    ],
    "Waterval": [
        "Waterval/Images/Waterval (Top)", 
        "Waterval/Images/Waterval (Bottom)",
        "Waterval/Images/Waterval (Overview)"
    ]
}

# Dictionary to hold year-month counts per facility: temporal_counts[facility][year][month_index] = count
temporal_counts = {fac: defaultdict(lambda: np.zeros(12, dtype=int)) for fac in FACILITIES}
all_years = set()

# 1. Parse filenames and aggregate counts
for facility, subdirs in FACILITIES.items():
    for subdir in subdirs:
        dir_path = RAW_DATA_ROOT / subdir
        if not dir_path.exists():
            continue
            
        for filepath in dir_path.iterdir():
            if filepath.suffix.lower() in IMAGE_EXTENSIONS:
                month, year = None, None
                
                # Try Pattern 1: MM_YYYY (e.g., 03_2024.jpg)
                match_mm_yyyy = re.search(r"(\d{2})_(\d{4})", filepath.name)
                if match_mm_yyyy:
                    month = int(match_mm_yyyy.group(1))
                    year = int(match_mm_yyyy.group(2))
                else:
                    # Try Pattern 2: _YYYYMM (e.g., capeflats2_200902.jpg)
                    match_yyyy_mm = re.search(r"_(\d{4})(\d{2})", filepath.name)
                    if match_yyyy_mm:
                        year = int(match_yyyy_mm.group(1))
                        month = int(match_yyyy_mm.group(2))
                
                # If valid dates were found, increment the count
                if month and year and 1 <= month <= 12:
                    temporal_counts[facility][year][month - 1] += 1
                    all_years.add(year)

# 2. Plotting the heatmaps
if not all_years:
    print("No valid images found matching the expected date patterns.")
else:
    sorted_years = sorted(list(all_years))
    months = [calendar.month_abbr[m] for m in range(1, 13)]

    # Create 3 subplots side-by-side
    fig, axes = plt.subplots(1, 3, figsize=(18, 8), sharey=True)
    
    # Calculate global max for consistent color mapping across all 3 plots
    global_max = max(
        count 
        for fac_data in temporal_counts.values() 
        for year_array in fac_data.values() 
        for count in year_array
    )

    for i, (facility, data) in enumerate(temporal_counts.items()):
        # Build a 2D array for the heatmap: rows = months, cols = years
        heatmap_data = np.zeros((12, len(sorted_years)), dtype=int)
        for y_idx, year in enumerate(sorted_years):
            heatmap_data[:, y_idx] = data[year]
        
        ax = axes[i]
        im = ax.imshow(heatmap_data, cmap="Blues", aspect='auto', vmin=0, vmax=global_max)
        
        # Axis formatting
        ax.set_title(f"{facility}", fontsize=14, weight='bold', pad=10)
        ax.set_xticks(np.arange(len(sorted_years)))
        ax.set_xticklabels(sorted_years, rotation=45, ha='right')
        
        if i == 0:
            ax.set_yticks(np.arange(12))
            ax.set_yticklabels(months, fontsize=12)
        
        # Add text annotations inside the heatmap cells
        for y_idx in range(len(sorted_years)):
            for m_idx in range(12):
                val = heatmap_data[m_idx, y_idx]
                if val > 0:
                    # Switch text color to white if the cell background is dark
                    text_color = "white" if val > (global_max * 0.6) else "black"
                    ax.text(y_idx, m_idx, str(val),
                            ha="center", va="center", color=text_color, fontsize=10)

    # Shared labels and title
    fig.supxlabel('Year', fontsize=14, weight='bold')
    fig.supylabel('Month', fontsize=14, weight='bold')
    fig.suptitle('Image Availability (Month vs. Year) per WWTW Facility', fontsize=16, weight='bold', y=0.98)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <h1>Summary Table</h1>

# %%
import pandas as pd
from pathlib import Path
from collections import defaultdict
from IPython.display import display

# Set this to your output root directory
DATASET_ROOT = Path("../cnn_dataset")
COMPONENTS = ["aerobic_zone", "clarifier"]

def get_clean_unit_name(filename):
    """Maps the safe filename prefix back to a clean facility/unit name."""
    if filename.startswith("Atlantis_Images"): return "Atlantis"
    if filename.startswith("CapeFlats_Images-CF1"): return "Cape Flats 1"
    if filename.startswith("CapeFlats_Images-CF2"): return "Cape Flats 2"
    if filename.startswith("CapeFlats_Images-CF3"): return "Cape Flats 3"
    if filename.startswith("CapeFlats_Images-CF4"): return "Cape Flats 4"
    if filename.startswith("Waterval_Images-Waterval_(Top)"): return "Waterval Top"
    if filename.startswith("Waterval_Images-Waterval_(Bottom)"): return "Waterval Bottom"
    return "Other"

# Dictionary to store counts: data[row_name][(component, class_name)] = count
data = defaultdict(lambda: defaultdict(int))
multi_cols = []

# Parse the directories and count the files
for comp in COMPONENTS:
    comp_dir = DATASET_ROOT / comp
    if not comp_dir.exists():
        continue
        
    classes = sorted([d.name for d in comp_dir.iterdir() if d.is_dir()])
    comp_display = comp.replace('_', ' ').title()
    
    for cls_name in classes:
        multi_cols.append((comp_display, cls_name))
        cls_dir = comp_dir / cls_name
        
        for img_path in cls_dir.glob("*.jpg"):
            unit_name = get_clean_unit_name(img_path.name)
            data[unit_name][(comp_display, cls_name)] += 1

# Define the logical row order for the table
row_order = [
    "Atlantis", 
    "Cape Flats 1", "Cape Flats 2", "Cape Flats 3", "Cape Flats 4", 
    "Waterval Top", "Waterval Bottom"
]

# Build the DataFrame
df = pd.DataFrame.from_dict(data, orient='index')

# Apply the MultiIndex for grouped column headers
df.columns = pd.MultiIndex.from_tuples(df.columns)

# Reindex to ensure all rows/cols are present (even if 0) and sort logically
df = df.reindex(index=row_order, columns=pd.MultiIndex.from_tuples(multi_cols)).fillna(0).astype(int)

# Append a Totals row at the bottom
df.loc['TOTAL'] = df.sum()

# Display the table with a light blue gradient to make it easy to scan
display(df.style.background_gradient(cmap='Blues', axis=None).format("{:.0f}"))
# Out:
# <style type="text/css">
# #T_35dae_row0_col0, #T_35dae_row3_col1, #T_35dae_row5_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_35dae_row0_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_35dae_row0_col2, #T_35dae_row3_col3, #T_35dae_row3_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_35dae_row0_col3, #T_35dae_row0_col4, #T_35dae_row4_col4, #T_35dae_row5_col4, #T_35dae_row5_col6, #T_35dae_row6_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_35dae_row0_col5, #T_35dae_row1_col2, #T_35dae_row4_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_35dae_row0_col6 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_35dae_row1_col0, #T_35dae_row6_col6 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_35dae_row1_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_35dae_row1_col3, #T_35dae_row3_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_35dae_row1_col4, #T_35dae_row2_col3 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_35dae_row1_col5 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_35dae_row1_col6, #T_35dae_row6_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_35dae_row2_col0 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_35dae_row2_col1, #T_35dae_row2_col2, #T_35dae_row4_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_35dae_row2_col4 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_35dae_row2_col5 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_35dae_row2_col6 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_35dae_row3_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_35dae_row3_col5 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_35dae_row3_col6 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_35dae_row4_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_35dae_row4_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_35dae_row4_col5 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_35dae_row4_col6, #T_35dae_row7_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_35dae_row5_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_35dae_row5_col1 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_35dae_row5_col3, #T_35dae_row5_col5 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_35dae_row6_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_35dae_row6_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_35dae_row6_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_35dae_row6_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_35dae_row7_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_35dae_row7_col1 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_35dae_row7_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_35dae_row7_col4 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_35dae_row7_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_35dae_row7_col6 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_35dae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35dae_level0_col0" class="col_heading level0 col0" colspan="3">Aerobic Zone</th>
#       <th id="T_35dae_level0_col3" class="col_heading level0 col3" colspan="4">Clarifier</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_35dae_level1_col0" class="col_heading level1 col0" >Dysfunctional</th>
#       <th id="T_35dae_level1_col1" class="col_heading level1 col1" >Functional</th>
#       <th id="T_35dae_level1_col2" class="col_heading level1 col2" >Suboptimal</th>
#       <th id="T_35dae_level1_col3" class="col_heading level1 col3" >Dysfunctional</th>
#       <th id="T_35dae_level1_col4" class="col_heading level1 col4" >Empty</th>
#       <th id="T_35dae_level1_col5" class="col_heading level1 col5" >Functional</th>
#       <th id="T_35dae_level1_col6" class="col_heading level1 col6" >Scum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35dae_level0_row0" class="row_heading level0 row0" >Atlantis</th>
#       <td id="T_35dae_row0_col0" class="data row0 col0" >14</td>
#       <td id="T_35dae_row0_col1" class="data row0 col1" >58</td>
#       <td id="T_35dae_row0_col2" class="data row0 col2" >19</td>
#       <td id="T_35dae_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_35dae_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_35dae_row0_col5" class="data row0 col5" >36</td>
#       <td id="T_35dae_row0_col6" class="data row0 col6" >52</td>
#     </tr>
#     <tr>
#       <th id="T_35dae_level0_row1" class="row_heading level0 row1" >Cape Flats 1</th>
#       <td id="T_35dae_row1_col0" class="data row1 col0" >113</td>
#       <td id="T_35dae_row1_col1" class="data row1 col1" >44</td>
#       <td id="T_35dae_row1_col2" class="data row1 col2" >37</td>
#       <td id="T_35dae_row1_col3" class="data row1 col3" >31</td>
#       <td id="T_35dae_row1_col4" class="data row1 col4" >60</td>
#       <td id="T_35dae_row1_col5" class="data row1 col5" >177</td>
#       <td id="T_35dae_row1_col6" class="data row1 col6" >76</td>
#     </tr>
#     <tr>
#       <th id="T_35dae_level0_row2" class="row_heading level0 row2" >Cape Flats 2</th>
#       <td id="T_35dae_row2_col0" class="data row2 col0" >146</td>
#       <td id="T_35dae_row2_col1" class="data row2 col1" >21</td>
#       <td id="T_35dae_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_35dae_row2_col3" class="data row2 col3" >60</td>
#       <td id="T_35dae_row2_col4" class="data row2 col4" >33</td>
#       <td id="T_35dae_row2_col5" class="data row2 col5" >181</td>
#       <td id="T_35dae_row2_col6" class="data row2 col6" >90</td>
#     </tr>
#     <tr>
#       <th id="T_35dae_level0_row3" class="row_heading level0 row3" >Cape Flats 3</th>
#       <td id="T_35dae_row3_col0" class="data row3 col0" >137</td>
#       <td id="T_35dae_row3_col1" class="data row3 col1" >15</td>
#       <td id="T_35dae_row3_col2" class="data row3 col2" >32</td>
#       <td id="T_35dae_row3_col3" class="data row3 col3" >19</td>
#       <td id="T_35dae_row3_col4" class="data row3 col4" >19</td>
#       <td id="T_35dae_row3_col5" class="data row3 col5" >209</td>
#       <td id="T_35dae_row3_col6" class="data row3 col6" >121</td>
#     </tr>
#     <tr>
#       <th id="T_35dae_level0_row4" class="row_heading level0 row4" >Cape Flats 4</th>
#       <td id="T_35dae_row4_col0" class="data row4 col0" >166</td>
#       <td id="T_35dae_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_35dae_row4_col2" class="data row4 col2" >22</td>
#       <td id="T_35dae_row4_col3" class="data row4 col3" >41</td>
#       <td id="T_35dae_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_35dae_row4_col5" class="data row4 col5" >129</td>
#       <td id="T_35dae_row4_col6" class="data row4 col6" >229</td>
#     </tr>
#     <tr>
#       <th id="T_35dae_level0_row5" class="row_heading level0 row5" >Waterval Top</th>
#       <td id="T_35dae_row5_col0" class="data row5 col0" >85</td>
#       <td id="T_35dae_row5_col1" class="data row5 col1" >344</td>
#       <td id="T_35dae_row5_col2" class="data row5 col2" >15</td>
#       <td id="T_35dae_row5_col3" class="data row5 col3" >71</td>
#       <td id="T_35dae_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_35dae_row5_col5" class="data row5 col5" >69</td>
#       <td id="T_35dae_row5_col6" class="data row5 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_35dae_level0_row6" class="row_heading level0 row6" >Waterval Bottom</th>
#       <td id="T_35dae_row6_col0" class="data row6 col0" >144</td>
#       <td id="T_35dae_row6_col1" class="data row6 col1" >199</td>
#       <td id="T_35dae_row6_col2" class="data row6 col2" >77</td>
#       <td id="T_35dae_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_35dae_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_35dae_row6_col5" class="data row6 col5" >26</td>
#       <td id="T_35dae_row6_col6" class="data row6 col6" >111</td>
#     </tr>
#     <tr>
#       <th id="T_35dae_level0_row7" class="row_heading level0 row7" >TOTAL</th>
#       <td id="T_35dae_row7_col0

# %% [markdown]
# ## Class balance (train split)

# %%
counts = np.bincount([label for _, label in train_ds.samples], minlength=num_classes)
for name, count in zip(class_names, counts):
    print(f"  {name:15s}: {count}")

plt.figure(figsize=(6, 4))
plt.bar(class_names, counts)
plt.ylabel("Number of images")
plt.title(f"Class distribution (Train) — {COMPONENT}")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()
# Out:
#   Dysfunctional  : 158
#   Empty          : 79
#   Functional     : 576
#   Scum           : 472

# %% [markdown]
# <h1>Class Example</h1>

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from pathlib import Path

# Set this to your output root directory
DATASET_ROOT = Path("../cnn_dataset")
COMPONENTS = ["aerobic_zone", "clarifier"]

def plot_class_examples(component):
    component_dir = DATASET_ROOT / component
    if not component_dir.exists():
        print(f"Directory not found: {component_dir}")
        return

    # Dynamically find classes (ignoring hidden files)
    classes = sorted([d.name for d in component_dir.iterdir() if d.is_dir()])
    
    if not classes:
        print(f"No classes found in {component_dir}")
        return

    # Create a subplot grid: 1 Row, len(classes) Columns
    fig, axes = plt.subplots(nrows=1, ncols=len(classes), 
                             figsize=(4 * len(classes), 4))
    
    # Handle the edge case if there is only 1 class
    if len(classes) == 1:
        axes = [axes]
        
    fig.suptitle(f"Class Examples: {component.replace('_', ' ').title()}", 
                 fontsize=16, weight='bold', y=1.05)

    for col_idx, cls_name in enumerate(classes):
        cls_dir = component_dir / cls_name
        # Grab all jpg images in this class folder
        all_files = list(cls_dir.glob("*.jpg")) 
        
        ax = axes[col_idx]
        
        if all_files:
            # Pick a random image from this class (ignoring facility)
            img_path = random.choice(all_files)
            img = mpimg.imread(str(img_path))
            ax.imshow(img)
            ax.set_title(cls_name, fontsize=14)
            ax.axis('off')
        else:
            # Completely remove the subplot if the class folder is empty
            ax.remove()
            
    plt.tight_layout()
    plt.show()

# Generate the visual grids for both components
for comp in COMPONENTS:
    plot_class_examples(comp)

# %% [markdown]
# ## Data source (facility) distribution across splits

# %%
from collections import defaultdict

splits = ['train', 'val', 'test']
split_facility_counts = {split: defaultdict(int) for split in splits}

for split in splits:
    split_dir = data_dir / split
    if not split_dir.exists():
        continue

    for class_dir in split_dir.iterdir():
        if not class_dir.is_dir():
            continue

        for img_path in class_dir.glob("*.*"):
            facility = img_path.name.split('_')[0]
            split_facility_counts[split][facility] += 1

all_facilities = sorted({
    facility
    for split_data in split_facility_counts.values()
    for facility in split_data.keys()
})

plot_data = {facility: [] for facility in all_facilities}

for split in splits:
    for facility in all_facilities:
        plot_data[facility].append(split_facility_counts[split].get(facility, 0))

fig, ax = plt.subplots(figsize=(8, 6))

bottoms = np.zeros(len(splits))

colors = plt.cm.Set2(np.linspace(0, 1, len(all_facilities)))

for idx, facility in enumerate(all_facilities):
    counts = np.array(plot_data[facility])
    ax.bar(splits, counts, label=facility, bottom=bottoms, color=colors[idx], width=0.6)
    bottoms += counts

ax.set_ylabel('Number of Images')
ax.set_title(f'Data Source Distribution Across Splits ({COMPONENT.replace("_", " ").title()})')
ax.legend(title="Facility Source", bbox_to_anchor=(1.05, 1), loc='upper left')

for i, total in enumerate(bottoms):
    ax.text(i, total + (max(bottoms)*0.02), f'{int(total)}', ha='center', fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Inspect a training batch (with augmentation applied)

# %%
images, labels = next(iter(train_loader))

fig, axes = plt.subplots(2, 4, figsize=(14, 5))
for ax, img, label in zip(axes.flatten(), images, labels):
    ax.imshow(denormalize(img).permute(1, 2, 0).numpy())
    ax.set_title(class_names[label])
    ax.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hyperparameter tuning summary (reference)
#
# The grid search / Bayesian-optimization results that `ARCH_HYPERPARAMS` in `wwtw_utils.py` was derived from, for reference.

# %%
print_tuning_summary()
# Out:
# Architecture grid search (best H, N per model):
#                  hidden_layers (H)  neurons (N)  val_accuracy_%
# model
# ResNet-50                        3         1024           97.37
# DenseNet-121                     3         2048           96.05
# InceptionNet v3                  3         2048           97.70
#
# Bayesian-optimized learning hyperparameters:
#                  learning_rate         beta1  step_size_Es  batch_size
# model
# ResNet-50             0.000027  1.788129e-01            34         121
# DenseNet-121          0.000274  4.149011e-17             7          14
# InceptionNet v3       0.000143  5.190841e-17            21          17
